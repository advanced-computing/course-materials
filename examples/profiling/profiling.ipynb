# %% [markdown]
# # Data profiling
#
# Using [Airbnb data](https://insideairbnb.com/).

# %%
import pandas as pd

airbnbs = pd.read_csv(
    "https://data.insideairbnb.com/united-states/ny/new-york-city/2025-12-04/data/listings.csv.gz"
)

# show all columns
pd.set_option("display.max_columns", None)

airbnbs
# Out:
#                         id                                       listing_url  \
# 0                     2539                 https://www.airbnb.com/rooms/2539
# 1                     2595                 https://www.airbnb.com/rooms/2595
# 2                     6848                 https://www.airbnb.com/rooms/6848
# 3                     6872                 https://www.airbnb.com/rooms/6872
# 4                     6990                 https://www.airbnb.com/rooms/6990
# ...                    ...                                               ...
# 36256  1567403299676323885  https://www.airbnb.com/rooms/1567403299676323885
# 36257  1567443344632413536  https://www.airbnb.com/rooms/1567443344632413536
# 36258  1567445948159672900  https://www.airbnb.com/rooms/1567445948159672900
# 36259  1567445949142407383  https://www.airbnb.com/rooms/1567445949142407383
# 36260  1567463073250285720  https://www.airbnb.com/rooms/1567463073250285720
#
# ...

# %%
airbnbs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36261 entries, 0 to 36260
# Data columns (total 85 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36261 non-null  int64
#  1   listing_url                                   36261 non-null  object
#  2   scrape_id                                     36261 non-null  int64
#  3   last_scraped                                  36261 non-null  object
#  4   source                                        36261 non-null  object
#  5   name                                          36259 non-null  object
#  6   description                                   34893 non-null  object
#  7   neighborhood_overview                         18130 non-null  object
#  8   picture_url                                   36261 non-null  object
# ...

# %%
airbnbs.describe(include="all")
# Out:
#                   id                        listing_url     scrape_id  \
# count   3.626100e+04                              36261  3.626100e+04
# unique           NaN                              36261           NaN
# top              NaN  https://www.airbnb.com/rooms/2539           NaN
# freq             NaN                                  1           NaN
# mean    4.875736e+17                                NaN  2.025120e+13
# std     5.626236e+17                                NaN  3.906304e-03
# min     2.539000e+03                                NaN  2.025120e+13
# 25%     2.175608e+07                                NaN  2.025120e+13
# 50%     5.172488e+07                                NaN  2.025120e+13
# 75%     1.005171e+18                                NaN  2.025120e+13
# max     1.567717e+18                                NaN  2.025120e+13
#
#        last_scraped       source                            name  \
# ...

# %% [markdown]
# After running the cell below, click `Open 'airbnbs' in [Data Wrangler](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.datawrangler)".

# %%
airbnbs
# Out:
#                         id                                       listing_url  \
# 0                     2539                 https://www.airbnb.com/rooms/2539
# 1                     2595                 https://www.airbnb.com/rooms/2595
# 2                     6848                 https://www.airbnb.com/rooms/6848
# 3                     6872                 https://www.airbnb.com/rooms/6872
# 4                     6990                 https://www.airbnb.com/rooms/6990
# ...                    ...                                               ...
# 36256  1567403299676323885  https://www.airbnb.com/rooms/1567403299676323885
# 36257  1567443344632413536  https://www.airbnb.com/rooms/1567443344632413536
# 36258  1567445948159672900  https://www.airbnb.com/rooms/1567445948159672900
# 36259  1567445949142407383  https://www.airbnb.com/rooms/1567445949142407383
# 36260  1567463073250285720  https://www.airbnb.com/rooms/1567463073250285720
#
# ...
